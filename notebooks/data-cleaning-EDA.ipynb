# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'_classic_test',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn',
#  u'seaborn-poster',
#  u'seaborn-bright',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %% [markdown]
# ## Cleanup Users and Repos dataframes

# %%
repos = pd.read_csv('data/new_subset_data/new_subset_repos.csv', sep='\t')
repos.info()
repos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069782 entries, 0 to 1069781
# Data columns (total 7 columns):
# id             1069782 non-null int64
# url            1069782 non-null object
# owner_id       1069782 non-null int64
# name           1069778 non-null object
# language       1069782 non-null object
# created_at     1069782 non-null object
# forked_from    1069782 non-null object
# dtypes: int64(2), object(5)
# memory usage: 57.1+ MB
#    id                                                url  owner_id       name  \
# 0   2  https://api.github.com/repos/kennethkalmer/ruo...         4  ruote-kit
# 1   3    https://api.github.com/repos/matplotlib/basemap        23    basemap
# 2   5   https://api.github.com/repos/funkaster/cocos2d-x        28  cocos2d-x
# 3   6     https://api.github.com/repos/cocos2d/cocos2d-x        31  cocos2d-x
# 4  10          https://api.github.com/repos/chapuni/llvm        67       llvm
#
#   language           created_at forked_from
# 0     Ruby  2009-06-10 20:32:21          \N
# 1      C++  2011-02-19 02:58:42          \N
# 2        C  2012-03-12 17:48:19           6
# 3      C++  2010-11-18 23:17:00          \N
# 4      C++  2011-02-01 09:11:48          \N

# %%
repos.id.sort_values().head()
# Out:
# 0     2
# 1     3
# 2     5
# 3     6
# 4    10
# Name: id, dtype: int64

# %%
repos.loc[repos.forked_from == '\N', 'forked_from'] = '0'

# %%
repos.forked_from = pd.to_numeric(repos.forked_from)

# %%
repos.created_at = pd.to_datetime(repos.created_at)

# %%
repos[repos.name.isnull()]
# Out:
# Empty DataFrame
# Columns: [id, url, owner_id, name, language, created_at, forked_from]
# Index: []

# %%
# repos.iloc[813370,3] = 'nan'

# %%
repos.to_pickle('data/pickled/new_subset_repos.pkl')

# %%
users = pd.read_csv('data/new_subset_data/new_subset_users.csv', sep='\t')
users.info()
users.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50008 entries, 0 to 50007
# Data columns (total 9 columns):
# id              50008 non-null int64
# login           50008 non-null object
# company         49988 non-null object
# created_at      50008 non-null object
# type            50008 non-null object
# country_code    50008 non-null object
# state           50008 non-null object
# city            50008 non-null object
# location        50007 non-null object
# dtypes: int64(1), object(8)
# memory usage: 3.4+ MB
#         id    login company           created_at type country_code state  \
# 0   421183   msizov      \N  2012-07-28 09:25:36  USR           \N    \N
# 1  8711566   Holy87      \N  2014-06-20 14:09:22  USR           \N    \N
# 2  1523784    ghswa      \N  2012-11-30 13:14:01  USR           gb    \N
# 3  5553551  yienren      \N  2013-04-13 12:01:22  USR           \N    \N
# 4  3742542    glurp      \N  2008-10-05 10:24:08  USR           fr   IdF
#
#     city       location
# 0     \N             \N
# 1     \N        Neaples
# 2     \N             UK
# 3     \N             \N
# 4  Paris  paris, france

# %%
users.location.fillna('\\N',inplace = True)
users.company.fillna('\\N',inplace = True)

# %%
users.created_at = pd.to_datetime(users.created_at)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50008 entries, 0 to 50007
# Data columns (total 9 columns):
# id              50008 non-null int64
# login           50008 non-null object
# company         50008 non-null object
# created_at      50008 non-null datetime64[ns]
# type            50008 non-null object
# country_code    50008 non-null object
# state           50008 non-null object
# city            50008 non-null object
# location        50008 non-null object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
users.to_pickle('data/pickled/new_subset_users.pkl')

# %% [markdown]
# ## Create Forked repo relationships between User -> Repo

# %%
repos = pd.read_pickle('data/pickled/new_subset_repos.pkl')
users = pd.read_pickle('data/pickled/new_subset_users.pkl')

# %%
repos.info()
print "-----------------------------------"
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069782 entries, 0 to 1069781
# Data columns (total 7 columns):
# id             1069782 non-null int64
# url            1069782 non-null object
# owner_id       1069782 non-null int64
# name           1069782 non-null object
# language       1069782 non-null object
# created_at     1069782 non-null datetime64[ns]
# forked_from    1069782 non-null int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 57.1+ MB
# -----------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50008 entries, 0 to 50007
# Data columns (total 9 columns):
# id              50008 non-null int64
# login           50008 non-null object
# company         50008 non-null object
# created_at      50008 non-null datetime64[ns]
# type            50008 non-null object
# country_code    50008 non-null object
# state           50008 non-null object
# city            50008 non-null object
# location        50008 non-null object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
forked = repos[['owner_id', 'forked_from', 'created_at']]
forked = forked.rename(columns={'owner_id': 'user_id', 'forked_from': 'repo_id'})
forked['forked'] = 4
forked.head()
forked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188865 entries, 0 to 1188864
# Data columns (total 4 columns):
# user_id       1188865 non-null int64
# repo_id       1188865 non-null int64
# created_at    1188865 non-null datetime64[ns]
# forked        1188865 non-null int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 36.3 MB

# %%
forked = forked[forked.repo_id != 0]
forked.info()
forked.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 343459 entries, 2 to 1188862
# Data columns (total 4 columns):
# user_id       343459 non-null int64
# repo_id       343459 non-null int64
# created_at    343459 non-null datetime64[ns]
# forked        343459 non-null int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 13.1 MB
#     user_id   repo_id          created_at  forked
# 2        28         6 2012-03-12 17:48:19       4
# 8        89   1262879 2011-12-25 14:51:08       4
# 17      178    207450 2011-10-27 01:17:37       4
# 18      208  12363088 2014-10-07 13:48:58       4
# 24      504        64 2012-06-08 03:13:55       4

# %%
repos[repos.id == 6]
# Out:
#    id                                             url  owner_id       name  \
# 3   6  https://api.github.com/repos/cocos2d/cocos2d-x        31  cocos2d-x
#
#   language          created_at  forked_from
# 3      C++ 2010-11-18 23:17:00            0

# %%
users[users.id == 28]
# Out:
# Empty DataFrame
# Columns: [id, login, company, created_at, type, country_code, state, city, location]
# Index: []

# %%
forked.to_pickle('data/pickled/new_subset_forks.pkl')

# %% [markdown]
# ## Create Owns relationship between User -> Repo
# #### A user who FORKED a repo also OWNS it, but a repo that a user OWNS was not necessarily FORKED.
# I don't think owning a repo versus forking a repo has any hierarchical relationship.
# So I'll use OWNS to denote a repo which was either forked or created by a user

# %%
repos = pd.read_pickle('data/pickled/new_subset_repos.pkl')

# %%
repos.info()
repos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069782 entries, 0 to 1069781
# Data columns (total 7 columns):
# id             1069782 non-null int64
# url            1069782 non-null object
# owner_id       1069782 non-null int64
# name           1069782 non-null object
# language       1069782 non-null object
# created_at     1069782 non-null datetime64[ns]
# forked_from    1069782 non-null int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 57.1+ MB
#    id                                                url  owner_id       name  \
# 0   2  https://api.github.com/repos/kennethkalmer/ruo...         4  ruote-kit
# 1   3    https://api.github.com/repos/matplotlib/basemap        23    basemap
# 2   5   https://api.github.com/repos/funkaster/cocos2d-x        28  cocos2d-x
# 3   6     https://api.github.com/repos/cocos2d/cocos2d-x        31  cocos2d-x
# 4  10          https://api.github.com/repos/chapuni/llvm        67       llvm
#
#   language          created_at  forked_from
# 0     Ruby 2009-06-10 20:32:21            0
# 1      C++ 2011-02-19 02:58:42            0
# 2        C 2012-03-12 17:48:19            6
# 3      C++ 2010-11-18 23:17:00            0
# 4      C++ 2011-02-01 09:11:48            0

# %%
owns = repos[['id', 'owner_id', 'forked_from', 'created_at']]
owns = owns.rename(columns={'id': 'repo_id', 'owner_id': 'user_id', 'forked_from': 'forked_from_repo_id'})
owns['owned'] = 4

# %%
owns.info()
owns.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069782 entries, 0 to 1069781
# Data columns (total 5 columns):
# repo_id                1069782 non-null int64
# user_id                1069782 non-null int64
# forked_from_repo_id    1069782 non-null int64
# created_at             1069782 non-null datetime64[ns]
# owned                  1069782 non-null int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 40.8 MB
#    repo_id  user_id  forked_from_repo_id          created_at  owned
# 0        2        4                    0 2009-06-10 20:32:21      4
# 1        3       23                    0 2011-02-19 02:58:42      4
# 2        5       28                    6 2012-03-12 17:48:19      4
# 3        6       31                    0 2010-11-18 23:17:00      4
# 4       10       67                    0 2011-02-01 09:11:48      4
# 5       11       69                    0 2011-05-16 21:41:09      4
# 6       19       78                    0 2009-01-05 14:00:43      4
# 7       23       86                    0 2011-08-23 02:30:04      4
# 8       27       89              1262879 2011-12-25 14:51:08      4
# 9       29      111                    0 2012-07-19 09:40:17      4

# %%
owns.to_pickle('data/pickled/new_subset_owns.pkl')

# %% [markdown]
# ## Create Starred relationship between User -> Repo

# %%
stars = pd.read_csv('data/new_subset_data/new_subset_stars.csv', sep='\t')
stars.info()
stars.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2268257 entries, 0 to 2268256
# Data columns (total 3 columns):
# repo_id       int64
# user_id       int64
# created_at    object
# dtypes: int64(2), object(1)
# memory usage: 51.9+ MB
#    repo_id  user_id           created_at
# 0      992   421183  2012-07-28 09:25:36
# 1     4077   421183  2012-08-21 08:24:15
# 2     4654   421183  2012-08-01 23:48:50
# 3    21985   421183  2012-07-28 09:25:36
# 4    26647   421183  2012-08-01 23:22:41

# %%
stars.created_at = pd.to_datetime(stars.created_at)
stars['starred'] = 2

# %%
stars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2268257 entries, 0 to 2268256
# Data columns (total 4 columns):
# repo_id       int64
# user_id       int64
# created_at    datetime64[ns]
# starred       int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 69.2 MB

# %%
stars.to_pickle('data/pickled/new_subset_starred.pkl')

# %% [markdown]
# ## Combine the Star & Own actions dfs to create implicit ratings
# #### I'm leaving out FORKS since a fork is always owned, but and owned repo is not always a fork

# %%
owns = pd.read_pickle('data/pickled/new_subset_owns.pkl')
stars = pd.read_pickle('data/pickled/new_subset_starred.pkl')

# %%
owns[['user_id', 'repo_id', 'created_at']].to_csv('data/new_subset_data/new_subset_owns.csv', sep='\t', index=False)

# %%
stars.info()
owns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2268257 entries, 0 to 2268256
# Data columns (total 4 columns):
# repo_id       int64
# user_id       int64
# created_at    datetime64[ns]
# starred       int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 69.2 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069782 entries, 0 to 1069781
# Data columns (total 5 columns):
# repo_id                1069782 non-null int64
# user_id                1069782 non-null int64
# forked_from_repo_id    1069782 non-null int64
# created_at             1069782 non-null datetime64[ns]
# owned                  1069782 non-null int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 40.8 MB

# %%
own_star = pd.merge(owns, stars, how='outer', on=['user_id', 'repo_id'], suffixes=('_own', '_star'))
own_star.info()
own_star.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3299450 entries, 0 to 3299449
# Data columns (total 7 columns):
# repo_id                int64
# user_id                int64
# forked_from_repo_id    float64
# created_at_own         datetime64[ns]
# owned                  float64
# created_at_star        datetime64[ns]
# starred                float64
# dtypes: datetime64[ns](2), float64(3), int64(2)
# memory usage: 201.4 MB
#    repo_id  user_id  forked_from_repo_id      created_at_own  owned  \
# 0        2        4                  0.0 2009-06-10 20:32:21    4.0
# 1        3       23                  0.0 2011-02-19 02:58:42    4.0
# 2        5       28                  6.0 2012-03-12 17:48:19    4.0
# 3        6       31                  0.0 2010-11-18 23:17:00    4.0
# 4       10       67                  0.0 2011-02-01 09:11:48    4.0
#
#       created_at_star  starred
# 0                 NaT      NaN
# 1                 NaT      NaN
# 2                 NaT      NaN
# 3                 NaT      NaN
# 4 2011-02-01 08:11:48      2.0

# %%
own_star['uniqueID'] = own_star.repo_id.astype(str) + own_star.user_id.astype(str)

# %%
#No duplicates between merging owns and stars on repo-user id combos
own_star[own_star.duplicated('uniqueID', keep=False)].shape
# Out:
# (0, 8)

# %%
own_star['rating'] = own_star[['starred','owned']].sum(axis=1)
own_star.head(20)
# Out:
#     repo_id  user_id  forked_from_repo_id      created_at_own  owned  \
# 0         2        4                  0.0 2009-06-10 20:32:21    4.0
# 1         3       23                  0.0 2011-02-19 02:58:42    4.0
# 2         5       28                  6.0 2012-03-12 17:48:19    4.0
# 3         6       31                  0.0 2010-11-18 23:17:00    4.0
# 4        10       67                  0.0 2011-02-01 09:11:48    4.0
# 5        11       69                  0.0 2011-05-16 21:41:09    4.0
# 6        19       78                  0.0 2009-01-05 14:00:43    4.0
# 7        23       86                  0.0 2011-08-23 02:30:04    4.0
# 8        27       89            1262879.0 2011-12-25 14:51:08    4.0
# 9        29      111                  0.0 2012-07-19 09:40:17    4.0
# 10       31      136                  0.0 2009-10-06 12:30:19    4.0
# 11       34      142                  0.0 2011-09-08 16:52:50    4.0
# 12       35      145                  0.0 2012-06-24 19:08:50    4.0
# 13       37      159                  0.0 2010-01-06 00:34:37    4.0
# 14       39      161                  0.0 2011-04-02 16:38:32    4.0
# 15       40      166                  0.0 2012-05-31 11:09:08    4.0
# 16       42      178             207450.0 2011-10-27 01:17:37    4.0
# 17       49      208           12363088.0 2014-10-07 13:48:58    4.0
# 18       52      216                  0.0 2009-12-02 06:46:03    4.0
# 19       55      272                  0.0 2008-12-05 19:12:24    4.0
#
#        created_at_star  starred uniqueID  rating
# 0                  NaT      NaN       24     4.0
# 1                  NaT      NaN      323     4.0
# 2                  NaT      NaN      528     4.0
# 3                  NaT      NaN      631     4.0
# 4  2011-02-01 08:11:48      2.0     1067     6.0
# 5                  NaT      NaN     1169     4.0
# 6                  NaT      NaN     1978     4.0
# 7                  NaT      NaN     2386     4.0
# 8                  NaT      NaN     2789     4.0
# 9                  NaT      NaN    29111     4.0
# 10                 NaT      NaN    31136     4.0
# 11                 NaT      NaN    34142     4.0
# 12                 NaT      NaN    35145     4.0
# 13                 NaT      NaN    37159     4.0
# 14                 NaT      NaN    39161     4.0
# 15                 NaT      NaN    40166     4.0
# 16                 NaT      NaN    42178     4.0
# 17                 NaT      NaN    49208     4.0
# 18                 NaT      NaN    52216     4.0
# 19                 NaT      NaN    55272     4.0

# %%
# Where repos are both owned and starred
(own_star[~own_star['starred'].isnull() & ~own_star['owned'].isnull()]).shape
# Out:
# (38589, 9)

# %%
own_star.sort_values(by=['user_id', 'repo_id']).head(10)
# Out:
#         repo_id  user_id  forked_from_repo_id      created_at_own  owned  \
# 33131    301466        1                  0.0 2010-02-09 11:41:12    4.0
# 167749  5074084        1                  0.0 2009-12-04 09:56:46    4.0
# 5789      25532        2                  0.0 2010-04-02 08:15:45    4.0
# 6662      28923        2                  0.0 2008-04-10 02:07:50    4.0
# 11001     49907        2                  0.0 2008-04-01 04:21:05    4.0
# 20790    133800        2                  0.0 2011-02-10 08:49:30    4.0
# 23925    169210        2                  0.0 2009-08-05 14:23:00    4.0
# 30803    258837        2                  0.0 2008-04-21 22:57:26    4.0
# 42365    504851        2                  0.0 2008-12-06 13:02:09    4.0
# 46809    623841        2                  0.0 2011-11-22 11:41:06    4.0
#
#        created_at_star  starred  uniqueID  rating
# 33131              NaT      NaN   3014661     4.0
# 167749             NaT      NaN  50740841     4.0
# 5789               NaT      NaN    255322     4.0
# 6662               NaT      NaN    289232     4.0
# 11001              NaT      NaN    499072     4.0
# 20790              NaT      NaN   1338002     4.0
# 23925              NaT      NaN   1692102     4.0
# 30803              NaT      NaN   2588372     4.0
# 42365              NaT      NaN   5048512     4.0
# 46809              NaT      NaN   6238412     4.0

# %%
own_star['created_at_star'] = own_star['created_at_star'].fillna(own_star['created_at_own'])

# %%
own_star.drop(['created_at_own'], axis=1, inplace=True)

# %%
own_star.rename(columns={'created_at_star': 'created_at'}, inplace=True)
own_star.head(10)
# Out:
#    repo_id  user_id  forked_from_repo_id  owned          created_at  starred  \
# 0        2        4                  0.0    4.0 2009-06-10 20:32:21      NaN
# 1        3       23                  0.0    4.0 2011-02-19 02:58:42      NaN
# 2        5       28                  6.0    4.0 2012-03-12 17:48:19      NaN
# 3        6       31                  0.0    4.0 2010-11-18 23:17:00      NaN
# 4       10       67                  0.0    4.0 2011-02-01 08:11:48      2.0
# 5       11       69                  0.0    4.0 2011-05-16 21:41:09      NaN
# 6       19       78                  0.0    4.0 2009-01-05 14:00:43      NaN
# 7       23       86                  0.0    4.0 2011-08-23 02:30:04      NaN
# 8       27       89            1262879.0    4.0 2011-12-25 14:51:08      NaN
# 9       29      111                  0.0    4.0 2012-07-19 09:40:17      NaN
#
#   uniqueID  rating
# 0       24     4.0
# 1      323     4.0
# 2      528     4.0
# 3      631     4.0
# 4     1067     6.0
# 5     1169     4.0
# 6     1978     4.0
# 7     2386     4.0
# 8     2789     4.0
# 9    29111     4.0

# %%
own_star.fillna(0, inplace=True)
own_star.head(20)
# Out:
#     repo_id  user_id  forked_from_repo_id  owned          created_at  starred  \
# 0         2        4                  0.0    4.0 2009-06-10 20:32:21      0.0
# 1         3       23                  0.0    4.0 2011-02-19 02:58:42      0.0
# 2         5       28                  6.0    4.0 2012-03-12 17:48:19      0.0
# 3         6       31                  0.0    4.0 2010-11-18 23:17:00      0.0
# 4        10       67                  0.0    4.0 2011-02-01 08:11:48      2.0
# 5        11       69                  0.0    4.0 2011-05-16 21:41:09      0.0
# 6        19       78                  0.0    4.0 2009-01-05 14:00:43      0.0
# 7        23       86                  0.0    4.0 2011-08-23 02:30:04      0.0
# 8        27       89            1262879.0    4.0 2011-12-25 14:51:08      0.0
# 9        29      111                  0.0    4.0 2012-07-19 09:40:17      0.0
# 10       31      136                  0.0    4.0 2009-10-06 12:30:19      0.0
# 11       34      142                  0.0    4.0 2011-09-08 16:52:50      0.0
# 12       35      145                  0.0    4.0 2012-06-24 19:08:50      0.0
# 13       37      159                  0.0    4.0 2010-01-06 00:34:37      0.0
# 14       39      161                  0.0    4.0 2011-04-02 16:38:32      0.0
# 15       40      166                  0.0    4.0 2012-05-31 11:09:08      0.0
# 16       42      178             207450.0    4.0 2011-10-27 01:17:37      0.0
# 17       49      208           12363088.0    4.0 2014-10-07 13:48:58      0.0
# 18       52      216                  0.0    4.0 2009-12-02 06:46:03      0.0
# 19       55      272                  0.0    4.0 2008-12-05 19:12:24      0.0
#
#    uniqueID  rating
# 0        24     4.0
# 1       323     4.0
# 2       528     4.0
# 3       631     4.0
# 4      1067     6.0
# 5      1169     4.0
# 6      1978     4.0
# 7      2386     4.0
# 8      2789     4.0
# 9     29111     4.0
# 10    31136     4.0
# 11    34142     4.0
# 12    35145     4.0
# 13    37159     4.0
# 14    39161     4.0
# 15    40166     4.0
# 16    42178     4.0
# 17    49208     4.0
# 18    52216     4.0
# 19    55272     4.0

# %%
own_star.drop('uniqueID', axis=1, inplace=True)

# %%
own_star.to_pickle('data/pickled/new_ratings_data.pkl')

# %% [markdown]
# ## Re-export final own-star data to csv with just user, repo, and ratings

# %%
own_star_2csv = own_star.drop(['forked_from_repo_id', 'owned', 'created_at', 'starred'], axis=1)
own_star_2csv = own_star_2csv.rename(columns={'repo_id': 'item', 'user_id': 'user'})
own_star_2csv[['user', 'item', 'rating']].to_csv('data/new_subset_data/ratings_data.csv', sep='\t', index=False)

# %% [markdown]
# ## Example of creating a user-to-all-items dataframe for predictions

# %%
ids = [1,3,56,83,34634,536352,45745]
user = 34
df = pd.DataFrame({'repo_id': ids, 'user_id': [user for i in range(len(ids))]})
df.head()
# Out:
#    repo_id  user_id
# 0        1       34
# 1        3       34
# 2       56       34
# 3       83       34
# 4    34634       34

# %% [markdown]
# https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.recommendation.ALS

# %%
final_data = pd.read_pickle('data/pickled/new_ratings_data.pkl')
final_data.info()
final_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3299450 entries, 0 to 3299449
# Data columns (total 7 columns):
# repo_id                int64
# user_id                int64
# forked_from_repo_id    float64
# owned                  float64
# created_at             datetime64[ns]
# starred                float64
# rating                 float64
# dtypes: datetime64[ns](1), float64(4), int64(2)
# memory usage: 201.4 MB
#    repo_id  user_id  forked_from_repo_id  owned          created_at  starred  \
# 0        2        4                  0.0    4.0 2009-06-10 20:32:21      0.0
# 1        3       23                  0.0    4.0 2011-02-19 02:58:42      0.0
# 2        5       28                  6.0    4.0 2012-03-12 17:48:19      0.0
# 3        6       31                  0.0    4.0 2010-11-18 23:17:00      0.0
# 4       10       67                  0.0    4.0 2011-02-01 08:11:48      2.0
#
#    rating
# 0     4.0
# 1     4.0
# 2     4.0
# 3     4.0
# 4     6.0

# %%
final_data.sort_values('created_at')
# Out:
#           repo_id   user_id  forked_from_repo_id  owned          created_at  \
# 3812        16462      9236                  0.0    4.0 2007-10-29 14:37:16
# 2867        12031     44511                  0.0    4.0 2008-01-12 16:46:52
# 14659       72450      9236                  0.0    4.0 2008-01-13 05:16:23
# 28788      225335      1570                  0.0    4.0 2008-01-14 03:32:19
# 17998      105156      1563                  0.0    4.0 2008-01-14 14:44:23
# 61259     1035597    213711             105156.0    4.0 2008-01-14 14:44:23
# 1375         5413      1563                  0.0    4.0 2008-01-14 14:51:56
# 5744        25384     78115                  0.0    4.0 2008-01-19 05:39:04
# 44364      556233      4567                  0.0    4.0 2008-01-19 22:55:05
# 40452      458080     28106               2968.0    4.0 2008-01-24 04:49:54
# 2574        10736     10005                  0.0    4.0 2008-01-27 17:23:23
# 1877         7644     23021                  0.0    4.0 2008-01-29 04:10:12
# 7144        31123      9236                  0.0    4.0 2008-01-29 06:48:49
# 28498      221444      1567                  0.0    4.0 2008-01-29 20:39:42
# 28271      218892      5995                  0.0    4.0 2008-01-30 23:20:38
# 934          3605     16372                  0.0    4.0 2008-02-01 04:27:00
# 60865     1022841      3892                  0.0    4.0 2008-02-02 11:28:47
# 2818321     12031     52422                  0.0    0.0 2008-02-03 13:59:12
# 2818325     16462     52422                  0.0    0.0 2008-02-03 13:59:12
# 45565      588361      9266                  0.0    4.0 2008-02-04 12:17:55
# 6877        29883     91657                  0.0    4.0 2008-02-06 22:33:31
# 79192     1716909    889397                  0.0    4.0 2008-02-08 03:55:18
# 4831        21280      2192                  0.0    4.0 2008-02-09 16:14:05
# 31256      267025      2192                  0.0    4.0 2008-02-09 16:20:11
# 19510      119078      2192                  0.0    4.0 2008-02-09 18:18:23
# 15734       82240     11855                  0.0    4.0 2008-02-10 20:21:42
# 7276        31720      1570                  0.0    4.0 2008-02-11 22:49:27
# 1722         6883     28799                  0.0    4.0 2008-02-11 22:55:26
# 17133       94852     14963                  0.0    4.0 2008-02-12 05:53:53
# 1340         5245      8931                  0.0    4.0 2008-02-14 02:20:50
# ...           ...       ...                  ...    ...                 ...
# 2751885  29171667   2834989                  0.0    0.0 2017-06-30 23:31:35
# 1069779  68501823   5851248           27679109.0    4.0 2017-06-30 23:33:54
# 2653490  10276679   3160460                  0.0    0.0 2017-06-30 23:34:44
# 2940000  66150059  11491091                  0.0    0.0 2017-06-30 23:35:08
# 1643905  10847503   6960938                  0.0    0.0 2017-06-30 23:35:49
# 1472050  55140467  32418569                  0.0    0.0 2017-06-30 23:35:55
# 2222639  67246517    401955                  0.0    0.0 2017-06-30 23:36:47
# 1472046  50702347  32418569                  0.0    0.0 2017-06-30 23:39:00
# 1643813     56393   6960938                  0.0    0.0 2017-06-30 23:39:25
# 2965381  10792942   9338700                  0.0    0.0 2017-06-30 23:40:05
# 2709610  64593545  13694008                  0.0    0.0 2017-06-30 23:40:17
# 1760309   4772856   3774813                  0.0    0.0 2017-06-30 23:40:37
# 1472047  50780594  32418569                  0.0    0.0 2017-06-30 23:41:05
# 1308469  19457765    155540                  0.0    0.0 2017-06-30 23:42:23
# 2948780  36495039  31123943                  0.0    0.0 2017-06-30 23:43:41
# 1959050  63590857   1578783                  0.0    0.0 2017-06-30 23:44:35
# 2038577  30056913    267586                  0.0    0.0 2017-06-30 23:46:52
# 2409817  68456097  30972312                  0.0    0.0 2017-06-30 23:47:56
# 1024545  64156470  31123943           53688873.0    4.0 2017-06-30 23:48:20
# 1069780  68502198    684086                  0.0    4.0 2017-06-30 23:48:57
# 1310480  67908847    155540                  0.0    0.0 2017-06-30 23:49:29
# 2038651  33722744    267586                  0.0    0.0 2017-06-30 23:49:57
# 2267889    687922    520414                  0.0    0.0 2017-06-30 23:50:49
# 2226994  53715765     88246                  0.0    0.0 2017-06-30 23:51:54
# 1126090  45916765   3250923                  0.0    0.0 2017-06-30 23:52:11
# 2277826  40940647   4030888                  0.0    0.0 2017-06-30 23:55:05
# 2604614  57610630  12224424                  0.0    0.0 2017-06-30 23:56:48
# 1069781  68502448  12224758                  0.0    4.0 2017-06-30 23:57:36
# 2589581  14537323   6462969                  0.0    0.0 2017-06-30 23:57:54
# 2965394  22218658   9338700                  0.0    0.0 2017-06-30 23:59:48
#
#          starred  rating
# 3812         0.0     4.0
# 2867         0.0     4.0
# 14659        0.0     4.0
# 28788        0.0     4.0
# 17998        0.0     4.0
# 61259        0.0     4.0
# 1375         0.0     4.0
# 5744         0.0     4.0
# 44364        0.0     4.0
# 40452        0.0     4.0
# 2574         0.0     4.0
# 1877         0.0     4.0
# 7144         0.0     4.0
# 28498        0.0     4.0
# 28271        0.0     4.0
# 934          0.0     4.0
# 60865        0.0     4.0
# 2818321      2.0     2.0
# 2818325      2.0     2.0
# 45565        0.0     4.0
# 6877         0.0     4.0
# 79192        0.0     4.0
# 4831         0.0     4.0
# 31256        0.0     4.0
# 19510        0.0     4.0
# 15734        0.0     4.0
# 7276         0.0     4.0
# 1722         0.0     4.0
# 17133        0.0     4.0
# 1340         0.0     4.0
# ...          ...     ...
# 2751885      2.0     2.0
# 1069779      0.0     4.0
# 2653490      2.0     2.0
# 2940000      2.0     2.0
# 1643905      2.0     2.0
# 1472050      2.0     2.0
# 2222639      2.0     2.0
# 1472046      2.0     2.0
# 1643813      2.0     2.0
# 2965381      2.0     2.0
# 2709610      2.0     2.0
# 1760309      2.0     2.0
# 1472047      2.0     2.0
# 1308469      2.0     2.0
# 2948780      2.0     2.0
# 1959050      2.0     2.0
# 2038577      2.0     2.0
# 2409817      2.0     2.0
# 1024545      2.0     6.0
# 1069780      0.0     4.0
# 1310480      2.0     2.0
# 2038651      2.0     2.0
# 2267889      2.0     2.0
# 2226994      2.0     2.0
# 1126090      2.0     2.0
# 2277826      2.0     2.0
# 2604614      2.0     2.0
# 1069781      0.0     4.0
# 2589581      2.0     2.0
# 2965394      2.0     2.0
#
# [3299450 rows x 7 columns]

# %%
def ordered_train_test_split(df, order_by, test_size=0.33):
    '''
    Takes a pandas dataframe and returns a train and test dataset ordered by the 
    column name passed to order_by and sliced up to the test_size
    INPUT:
    df: pandas df
    order_by: list or str of column names
    test_size: float percentage of df to use as test set
    OUTPUT:
    train: pandas dataframe
    test: pandas dataframe
    '''
    upto = int(df.shape[0] * (1 - test_size))
    df = df.sort_values(by=order_by, axis=0)
    train = df.iloc[:upto,:]
    test = df.iloc[upto:,:]
    return train, test

# %%
train_df, test_df = ordered_train_test_split(final_data, 'created_at')
train_df.drop('created_at', axis=1, inplace=True)
test_df.drop('created_at', axis=1, inplace=True)

# %%
train_df[['user_id', 'repo_id', 'rating']].to_csv('data/new_subset_data/final_train_data.csv', index=False)
test_df[['user_id', 'repo_id', 'rating']].to_csv('data/new_subset_data/final_test_data.csv', index=False)

# %%
users[users.id == 9236]
# Out:
# Empty DataFrame
# Columns: [id, login, company, created_at, type, country_code, state, city, location]
# Index: []

# %%
plt.hist(final_data.rating)
plt.title('Starred, Owned, and Both')
plt.ylabel("Count")
plt.savefig('/home/ubuntu/PROJECT/github-collaborator/matplots/star_own_distribution.png');

# %%
traindata = pd.read_csv('data/new_subset_data/final_train_data.csv')
testdata = pd.read_csv('data/new_subset_data/final_test_data.csv')

# %%
plt.hist(traindata.rating)
plt.title("Training Data Star to Own Distribution");

# %%
plt.hist(testdata.rating)
plt.title("Testing Data Star to Own Distribution");

# %% [markdown]
# ## Number of stars, owns (includes forks), and starred&owned
# #### Interest level shouldn't be higher just beacuse a repo is both starred and forked, so I'll write over any 6 ratings with 4 later, but there are so few of these anyway.

# %%
final_data.groupby('rating').agg(['count'])
# Out:
#            user     item
#           count    count
# rating
# 2.0     2229668  2229668
# 4.0     1031193  1031193
# 6.0       38589    38589

# %% [markdown]
# ## Check unique repo and users in final merged data

# %%
repos = pd.read_csv('data/new_subset_data/new_subset_repos.csv', sep='\t')
users = pd.read_csv('data/new_subset_data/new_subset_users.csv', sep='\t')
owns = pd.read_csv('data/new_subset_data/new_subset_owns.csv', sep='\t')
stars = pd.read_csv('data/new_subset_data/new_subset_stars.csv', sep='\t')
final_data = pd.read_csv('data/new_subset_data/ratings_data.csv', sep='\t')

# %%
len(repos.id.unique())
# Out:
# 1069782

# %%
len(final_data.item.unique())
# Out:
# 1069782

# %% [markdown]
# # Log Number of Commits per Repo

# %%
commits = pd.read_pickle('data/pickled/commits.pkl')
commits.head()
# Out:
#     repo_id  user_id  commits  log_commits
# 0         1        1        9     2.197225
# 1  51746271        1       10     2.302585
# 2  56271530        1       15     2.708050
# 3  63915386        1       14     2.639057
# 4         1        2       48     3.871201

# %%
plt.hist(commits.log_commits, bins=50)
plt.xlim((1,8))
plt.title('Distribution of Commits per Repo')
plt.xlabel('Log(commits per repo)')
plt.ylabel('Count')
#fig.savefig('/home/ubuntu/PROJECT/github-collaborator/matplots/distribution_of_commits.png');

# %%
commits['log10_commits'] = np.log10(commits['commits'])

# %%
plt.hist(commits.log10_commits, bins=50)
plt.xlim((0.5,3))
plt.title('Distribution of Commits per Repo')
plt.xlabel('Log10(commits per repo)')
plt.ylabel('Count');

# %%
commits_per_repo = pd.read_pickle('data/pickled/commits.pkl')
commits_per_repo.info()
# Out:
#     repo_id  user_id  commits  log_commits  log10_commits
# 0         1        1        9     2.197225       0.954243
# 1  51746271        1       10     2.302585       1.000000
# 2  56271530        1       15     2.708050       1.176091
# 3  63915386        1       14     2.639057       1.146128
# 4         1        2       48     3.871201       1.681241

# %%
from sklearn.model_selection import train_test_split

# %%
train_commits, test_commits = train_test_split(commits_per_repo, test_size=0.33)

# %%
train_commits[['user_id', 'repo_id', 'log10_commits']].to_csv('data/new_subset_data/train_commits.csv', index=False)
test_commits[['user_id', 'repo_id', 'log10_commits']].to_csv('data/new_subset_data/test_commits.csv', index=False)

# %%
commits_per_repo[['user_id', 'repo_id', 'log10_commits']].to_csv('data/new_subset_data/entire_commits.csv', index=False)
